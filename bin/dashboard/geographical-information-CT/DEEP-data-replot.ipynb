# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Sample data
categories = ["Transportation", "Residential", "Electric Power (Consumption)", "Commercial", "Industrial", "Waste","Agriculture","Natural gas leakage"]
values = [40,19,15,11,8,6,1,0]

plt.figure(figsize=(8, 8))  # Increase the figure size
plt.pie(values, labels=None, autopct='%1.1f%%', startangle=90)

# Create the legend with a specified location
legend = plt.legend(categories, loc=(0.9, 0.1))  # Adjust the values (0.8, 0.5) to move the legend left

# Display the chart
#plt.show()
plt.savefig('../../../figures/piechart_from_DEEP.png', dpi=600,bbox_inches='tight')
