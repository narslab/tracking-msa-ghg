# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')

# Load two more MSAs
# Replace the file paths with the paths to your shapefiles
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(10, 10))

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA
NHM_msa.boundary.plot(ax=ax, linewidth=1, color='red')

# Plot the second MSA with a different color (e.g., blue)
HEM_msa.boundary.plot(ax=ax, linewidth=1, color='blue')

# Plot the third MSA with another different color (e.g., green)
BSN_msa.boundary.plot(ax=ax, linewidth=1, color='green')

# Set the aspect ratio to be equal and set the title
ax.set_aspect('equal')
ax.set_title('Connecticut Counties and MSAs Map')

# Show the map
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')

# Load two more MSAs
# Replace the file paths with the paths to your shapefiles
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(10, 10))

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA and fill it with red
NHM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
NHM_msa.plot(ax=ax, facecolor='red', alpha=0.5)  # You can adjust the alpha for transparency

# Plot the Hartford-East Hartford-Middletown MSA, fill it with blue
HEM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
HEM_msa.plot(ax=ax, facecolor='blue', alpha=0.5)  # You can adjust the alpha for transparency

# Plot the Bridgeport-Stamford-Norwalk MSA, fill it with green
BSN_msa.boundary.plot(ax=ax, linewidth=1, color='black')
BSN_msa.plot(ax=ax, facecolor='green', alpha=0.5)  # You can adjust the alpha for transparency

# Set the aspect ratio to be equal and set the title
ax.set_aspect('equal')
ax.set_title('Connecticut and three MSAs Map')

# Show the map
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')

# Load two more MSAs
# Replace the file paths with the paths to your shapefiles
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(15, 15))

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA and fill it with red
NHM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
NHM_msa.plot(ax=ax, facecolor='red', alpha=0.5)

# Plot the Hartford-East Hartford-Middletown MSA, fill it with blue
HEM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
HEM_msa.plot(ax=ax, facecolor='blue', alpha=0.5)

# Plot the Bridgeport-Stamford-Norwalk MSA, fill it with green
BSN_msa.boundary.plot(ax=ax, linewidth=1, color='black')
BSN_msa.plot(ax=ax, facecolor='green', alpha=0.5)

# Set the aspect ratio to be equal and set the title
ax.set_aspect('equal')
ax.set_title('Connecticut Counties and MSAs Map')

# Add labels inside each MSA polygon
for idx, row in NHM_msa.iterrows():
    ax.annotate(text='New Haven-Milford', xy=row['geometry'].centroid.coords[0], ha='center', va='center', fontsize=12)
for idx, row in HEM_msa.iterrows():
    ax.annotate(text='Hartford-east Hartford-Middletown', xy=row['geometry'].centroid.coords[0], ha='center', va='center', fontsize=12)
for idx, row in BSN_msa.iterrows():
    ax.annotate(text='Bridgeport-Stamford-Norwalk', xy=row['geometry'].centroid.coords[0], ha='center', va='center', fontsize=12)

# Show the map
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D


# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')

# Load two more MSAs
# Replace the file paths with the paths to your shapefiles
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(15, 15))

ax.set_axis_off()

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA and fill it with red
NHM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
NHM_msa.plot(ax=ax, facecolor='red', alpha=0.5)

# Plot the Hartford-East Hartford-Middletown MSA, fill it with blue
HEM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
HEM_msa.plot(ax=ax, facecolor='blue', alpha=0.5)

# Plot the Bridgeport-Stamford-Norwalk MSA, fill it with green
BSN_msa.boundary.plot(ax=ax, linewidth=1, color='black')
BSN_msa.plot(ax=ax, facecolor='green', alpha=0.5)

ax.set_aspect('equal')
#ax.set_title('Connecticut and MSAs Map')

# Create custom legend handles with matching colors for the legend
legend_handles = [
    Line2D([0], [0], color='red', lw=5, label='New Haven-Milford MSA'),
    Line2D([0], [0], color='blue', lw=5, label='Hartford-East Hartford-Middletown MSA'),
    Line2D([0], [0], color='green', lw=5, label='Bridgeport-Stamford-Norwalk MSA'),
]

# Add a custom legend to the map with transparent background
legend = ax.legend(handles=legend_handles, fontsize=12, loc='lower right', frameon=False)
# Show the map
#plt.show()
plt.savefig('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/figures/Connecticut_MSA_Map.png', dpi=100,bbox_inches='tight')

# %%
import geopandas as gpd

# Load the shapefile containing city boundaries
Harford_gdf = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford City.shp')
Newhaven_gdf = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven City.shp')
Waterbury_gdf = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Waterbury city.shp')


# Extract the longitude and latitude for Hartford's centroid
longitude1, latitude1 = Harford_gdf.centroid.x.values[0], Harford_gdf.centroid.y.values[0]
longitude2, latitude2 = Newhaven_gdf.centroid.x.values[0], Newhaven_gdf.centroid.y.values[0]
longitude3, latitude3 = Waterbury_gdf.centroid.x.values[0], Waterbury_gdf.centroid.y.values[0]
# Out:
# C:\Users\peiyaozhao\AppData\Local\Temp\ipykernel_2948\2603627509.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   longitude1, latitude1 = Harford_gdf.centroid.x.values[0], Harford_gdf.centroid.y.values[0]
# C:\Users\peiyaozhao\AppData\Local\Temp\ipykernel_2948\2603627509.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   longitude2, latitude2 = Newhaven_gdf.centroid.x.values[0], Newhaven_gdf.centroid.y.values[0]
# C:\Users\peiyaozhao\AppData\Local\Temp\ipykernel_2948\2603627509.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D


# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')

# Load two more MSAs
# Replace the file paths with the paths to your shapefiles
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(15, 15))

ax.set_axis_off()

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA and fill it with red
NHM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
NHM_msa.plot(ax=ax, facecolor='red', alpha=0.5)

# Plot the Hartford-East Hartford-Middletown MSA, fill it with blue
HEM_msa.boundary.plot(ax=ax, linewidth=1, color='black')
HEM_msa.plot(ax=ax, facecolor='blue', alpha=0.5)

# Plot the Bridgeport-Stamford-Norwalk MSA, fill it with green
BSN_msa.boundary.plot(ax=ax, linewidth=1, color='black')
BSN_msa.plot(ax=ax, facecolor='green', alpha=0.5)

ax.set_aspect('equal')
#ax.set_title('Connecticut and MSAs Map')

# Create custom legend handles with matching colors for the legend
legend_handles = [
    Line2D([0], [0], color='red', lw=5, label='New Haven-Milford MSA'),
    Line2D([0], [0], color='blue', lw=5, label='Hartford-East Hartford-Middletown MSA'),
    Line2D([0], [0], color='green', lw=5, label='Bridgeport-Stamford-Norwalk MSA'),
]

# Add a custom legend to the map with transparent background
legend = ax.legend(handles=legend_handles, fontsize=12, loc='lower right', frameon=False)
# Show the map
#plt.show()



cities = {
    'New Haven': (longitude2, latitude2),
    'Hartford': (longitude1, latitude1),
    'Waterbury': (longitude3, latitude3),
    'Bridgeport': (-73.195557,41.186390),
}

for city, (lon, lat) in cities.items():
    ax.scatter(lon, lat, color='black', s=50, marker="*", label=city)
    ax.annotate(text=city, xy=(lon, lat), xytext=(lon, lat + 0.02), ha='center', va='bottom', fontsize=15)


# Add a custom legend to the map with transparent background (your code here)

# Show the map
plt.savefig('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/figures/Connecticut_MSA_cities.png', dpi=100,bbox_inches='tight')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.lines import Line2D
from matplotlib.colors import ListedColormap

# Load the shapefiles for Connecticut counties and MSAs
ct_counties = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Connecticut.shp')
NHM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/New Haven-Milford MSA.shp')
HEM_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Hartford-east Hartford-Middletown MSA.shp')
BSN_msa = gpd.read_file('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/data/raw/Bridgeport-Stamford-Norwalk MSA.shp')

# Load population data for each MSA
NHM_population = 864751  # Replace with actual population data
HEM_population = 1213324  # Replace with actual population data
BSN_population = 956446   # Replace with actual population data

# Merge population data with the GeoDataFrames
NHM_msa['population'] = NHM_population
HEM_msa['population'] = HEM_population
BSN_msa['population'] = BSN_population

# Create a new figure and axis for the map
fig, ax = plt.subplots(figsize=(15, 15))
ax.set_axis_off()

# Plot Connecticut counties
ct_counties.boundary.plot(ax=ax, linewidth=1, color='black')

# Plot the New Haven-Milford MSA with population-based colormap
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

vmin = min(NHM_population, HEM_population, BSN_population)
vmax = max(NHM_population, HEM_population, BSN_population)

# Plot the New Haven-Milford MSA with a population-based colormap and adjusted range
NHM_msa.plot(ax=ax, column='population', cmap='viridis', alpha=0.7, legend=True, cax=cax, vmin=vmin, vmax=vmax)

# Plot the Hartford-East Hartford-Middletown MSA with a population-based colormap and adjusted range
HEM_msa.plot(ax=ax, column='population', cmap='viridis', alpha=0.7, legend=True, cax=cax, vmin=vmin, vmax=vmax)

# Plot the Bridgeport-Stamford-Norwalk MSA with a population-based colormap and adjusted range
BSN_msa.plot(ax=ax, column='population', cmap='viridis', alpha=0.7, legend=True, cax=cax, vmin=vmin, vmax=vmax)

ax.set_aspect('equal')

# Create a custom colormap for the legend
legend_cmap = ListedColormap(['#440154', '#21918C', '#FDE725'])  # Change these colors to match your heatmap

# Create custom legend handles with matching colors for the legend
legend_handles = [
    Line2D([0], [0], color=legend_cmap(0.2), lw=5, label='New Haven-Milford'),
    Line2D([0], [0], color=legend_cmap(0.5), lw=5, label='Bridgeport-Stamford-Norwalk'),
    Line2D([0], [0], color=legend_cmap(0.8), lw=5, label='Hartford-East Hartford-Middletown'),
]

# Add a custom legend to the map with transparent background
legend = ax.legend(handles=legend_handles, fontsize=12, loc='lower right', frameon=False)
#legend.set_title('MSAs')



cities = {
    'New Haven': (longitude2, latitude2),
    'Hartford': (longitude1, latitude1),
    'Waterbury': (longitude3, latitude3),
    'Bridgeport': (-73.195557,41.186390),
}

for city, (lon, lat) in cities.items():
    ax.scatter(lon, lat, color='black', s=50, marker="*", label=city)
    ax.annotate(text=city, xy=(lon, lat), xytext=(lon, lat + 0.02), ha='center', va='bottom', fontsize=15)

# Show the map
plt.savefig('C:/Users/peiyaozhao/Documents/GitHub/tracking-msa-ghg/figures/Connecticut_MSA_heatmap.png', dpi=100,bbox_inches='tight')
